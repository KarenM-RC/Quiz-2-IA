# %% [markdown]
# <a href="https://colab.research.google.com/github/KarenM-RC/Quiz-2-IA/blob/main/Quiz2_AG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Algoritmo Genético
Quiz # 2 - Inteligencia Artificial 
Laura Daniela Gonzalez Alvarez
Jhoan Nicolas Palomino Posada
Karen Melissa Ramírez Casas
"""

alfabeto = 'aábcdefghiíjklmnñopqrstuvwxyzABCDEFGHIJKLMNÑOPQRSTUVWXYZ, '
objetivo = 'Ingeniería informática, inteligencia artificial'

import datetime
import random

tiempoDeInicio = datetime.datetime.now()

#Generar de manera aleatoria una muestra de genes
def generarPadre(largo):
    genes = [] #Inicializa la lista de la secuencia aleatoria
    while len(genes) < largo: #Largo es la longitud de la cadena objetivo
        tamañoMuestra = min(largo - len(genes), len(alfabeto))#Numero más pequeño entre el largo - longitud (actual) de genes y la longitud del alfabeto
        genes.extend(random.sample(alfabeto,tamañoMuestra)) #Devuelve tantos elementos del alfabeto aleatorios como el tamaño de muestra y junta la cadena genes con los datos de alfabeto
    return ''.join(genes) #une los caracteres de la cadena genes sin separaciones
    
#Funcion fitness, si la posición en la muestra aleatoria tiene un caracter igual en la misma posición de nuestro objetivo se suma 1 al fitness
def algoritmoFitness(carIgual):
  fitness = 0
  for i in range(len(objetivo)):
    if objetivo[i] == carIgual[i]:
        fitness = fitness + 1
  return fitness

#Funcion para mutar a nuestra cadena original o padre
def mutar(padre):
    indice = random.randrange(0,len(padre))#Devuelve un número entre 0 y el tamaño de la lista
    genesDelHijo = list(padre)#crea una lista que contenga lo de la lista padre
    genNuevo, alternar = random.sample(alfabeto,2)#Devuelve 2 elementos aleatorios de la lista alfabeto, uno para genNuevo y otro para alternar
    if genNuevo == genesDelHijo[indice]:
      genesDelHijo[indice] = alternar
    else:
      genesDelHijo[indice] = genNuevo
    return ''.join(genesDelHijo)#une los caracteres de la cadena genesDelHijo sin separaciones

#Funcion para imprimir en pantalla los resultados
def imprimir(resultado,g):
    diferenciaDeTiempo = datetime.datetime.now() - tiempoDeInicio
    fitness = algoritmoFitness(resultado)
    print('{}\t{}\t{}\t{}'.format(g,resultado,fitness,diferenciaDeTiempo))


#Inicializamos nuestros parametros
print('{}\t{}\t{}\t{}'.format("GENERACION","RESULTADO","                        FITNESS","DIFERENCIA DE TIEMPO"))
generacion=0
mejorPadre = generarPadre(len(objetivo))
mejorFitness = algoritmoFitness(mejorPadre)
imprimir(mejorPadre,generacion)


#Creamos un ciclo para iterar nuestras funciones
#Hasta obtener nuestro objetivo
while True:
    generacion = generacion + 1
    hijo = mutar(mejorPadre)
    hijoConFitness = algoritmoFitness(hijo)
    if mejorFitness >= hijoConFitness:
        continue
    imprimir(hijo,generacion)
    if hijoConFitness >= len(mejorPadre):
        break
    mejorFitness = hijoConFitness
    mejorPadre = hijo
# Out:
# GENERACION	RESULTADO	                        FITNESS	DIFERENCIA DE TIEMPO
# 0	taFíbKHzWAVQCUNkPJXuIñTESwxfáomcvYGpÑOZijRMyg,n	0	0:00:00.001712
# 17	taFíbKHzWAVQCUNkPJXuIñTESwxfáomcvYGpÑOZijRMyi,n	1	0:00:00.002379
# 90	taFíbKHzWAVQCUNkPJXuIñTESnxfáomcvYGpÑOZijRMyi,n	2	0:00:00.004504
# 112	taFínKHzWAVQCUNkPJXuIñTESnxfáomcvYGpÑOZijRMyi,n	3	0:00:00.005143
# 146	taFínKHzWAVQCUNkPJXuIñTESnxfáomevYGpÑOZijRMyi,n	4	0:00:00.006192
# 191	taFínKHzWAVQCUNkPJXuIñTESnxfáomevYGpÑOZijRMci,n	5	0:00:00.006905
# 308	taFínKHzWAVQCUNkPJXuIñTESnxfáomevYipÑOZijRMci,n	6	0:00:00.008795
# 327	taFínKHzWAVQCUNkPáXuIñTESnxfáomevYipÑOZijRMci,n	7	0:00:00.009163
# 330	taFínKHzWA QCUNkPáXuIñTESnxfáomevYipÑOZijRMci,n	8	0:00:00.009276
# 375	taFínKHzWA QCUNkPáXucñTESnxfáomevYipÑOZijRMci,n	9	0:00:00.010614
# 404	taFínKHzWA QCUNkPáXucñTESnxfáomevYiaÑOZijRMci,n	10	0:00:00.011104
# 458	taFínKHzWA QCUNkPáXicñTESnxfáomevYiaÑOZijRMci,n	11	0:00:00.011911
# 473	taFínKHzWA QCUNrPáXicñTESnxfáomevYiaÑOZijRMci,n	12	0:00:00.014164
# 507	taFínKHzWA QCUNrPáXicñTESnxfáomevYia OZijRMci,n	13	0:00:00.014850
# 544	tnFínKHzWA QCUNrPáXicñTESnxfáomevYia OZijRMci,n	14	0:00:00.016023
# 615	tnFínKHzíA QCUNrPáXicñTESnxfáomevYia OZijRMci,n	15	0:00:00.017256
# 666	tnFíniHzíA QCUNrPáXicñTESnxfáomevYia OZijRMci,n	16	0:00:00.018113
# 881	tnFíniHzíA iCUNrPáXicñTESnxfáomevYia OZijRMci,n	17	0:00:00.021258
# 906	tnFíniHzíA inUNrPáXicñTESnxfáomevYia OZijRMci,n	18	0:00:00.021707
# 948	tnFíniHzíA inUNrPáXicñTESnxfáomevYia OZijfMci,n	19	0:00:00.022360
# 1027	tnFíniHzíA inUorPáXicñTESnxfáomevYia OZijfMci,n	20	0:00:00.023523
# 1087	tnFíniHzíA inUorPáticñTESnxfáomevYia OZijfMci,n	21	0:00:00.028308
# 1229	tnFíniHzíA inUorPáticñTESntfáomevYia OZijfMci,n	22	0:00:00.030457
# 1533	tnFíniHzíA inUorPáticñTESntfáimevYia OZijfMci,n	23	0:00:00.034954
# 1819	tnFíniHzíA inUorPáticñTESntfáimevYia OZijfici,n	24	0:00:00.039162
# 2073	tnFíniHzíA inUorPáticñTEintfáimevYia OZijfici,n	25	0:00:00.042926
# 2094	tnFíniHzíA inUorPáticñTEintfáimevYia OZiifici,n	26	0:00:00.043460
# 2129	tnFeniHzíA inUorPáticñTEintfáimevYia OZiifici,n	27	0:00:00.044061
# 2282	tngeniHzíA inUorPáticñTEintfáimevYia OZiifici,n	28	0:00:00.046347
# 2337	tngeniHzíA inUorPáticñT intfáimevYia OZiifici,n	29	0:00:00.048928
# 2373	tngeniHzíA inUorPáticñT inteáimevYia OZiifici,n	30	0:00:00.051897
# 2506	tngeniHzíA inUorPáticñT inteáimevYia OZtifici,n	31	0:00:00.053917
# 2516	tngeniHzíA inforPáticñT inteáimevYia OZtifici,n	32	0:00:00.054131
# 2670	tngeniHzíA inforPáticñT inteáimevcia OZtifici,n	33	0:00:00.056410
# 3271	tngeniHzíA inforPáticñT inteáimevcia Ortifici,n	34	0:00:00.065630
# 4814	tngeniHzíA inforPáticñT inteáimevcia Ortifician	35	0:00:00.092715
# 4896	tngeniHríA inforPáticñT inteáimevcia Ortifician	36	0:00:00.094103
# 5192	tngenieríA inforPáticñT inteáimevcia Ortifician	37	0:00:00.098466
# 5698	tngenieríA inforPáticñ, inteáimevcia Ortifician	38	0:00:00.107371
# 6114	tngenieríA inforPáticñ, inteáimencia Ortifician	39	0:00:00.114410
# 6840	IngenieríA inforPáticñ, inteáimencia Ortifician	40	0:00:00.125682
# 7155	IngenieríA inforPáticñ, inteáimencia artifician	41	0:00:00.130391
# 8233	IngenieríA inforPática, inteáimencia artifician	42	0:00:00.147166
# 8242	IngenieríA inforPática, inteáigencia artifician	43	0:00:00.147550
# 8488	IngenieríA informática, inteáigencia artifician	44	0:00:00.152217
# 8957	IngenieríA informática, inteligencia artifician	45	0:00:00.159959
# 9248	Ingeniería informática, inteligencia artifician	46	0:00:00.166321
# 13844	Ingeniería informática, inteligencia artificial	47	0:00:00.240787
