# %% [markdown]
# <a href="https://colab.research.google.com/github/KarenM-RC/Quiz-2-IA/blob/main/Quiz2_AG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Algoritmo Genético
Quiz # 2 - Inteligencia Artificial 
Laura Daniela Gonzalez 
Jhoan Nicolas Palomino Posada
Karen Melissa Ramírez Casas
"""

alfabeto = 'aábcdefghiíjklmnñopqrstuvwxyzABCDEFGHIJKLMNÑOPQRSTUVWXYZ, '
objetivo = 'Ingeniería informática, inteligencia artificial'

import datetime
import random

tiempoDeInicio = datetime.datetime.now()

#Generar de manera aleatoria una muestra de genes
def generarPadre(largo):
    genes = [] #Inicializa la lista de la secuencia aleatoria
    while len(genes) < largo: #Largo es la longitud de la cadena objetivo
        tamañoMuestra = min(largo - len(genes), len(alfabeto))#Numero más pequeño entre el largo - longitud (actual) de genes y la longitud del alfabeto
        genes.extend(random.sample(alfabeto,tamañoMuestra)) #Se obtiene la muestra aleatoria, junta las cadena genes con los datos de alfabeto
    return ''.join(genes) #une los caracteres de la cadena genes sin separaciones
    
#Funcion fitness, si la posición en la muestra aleatoria tiene un caracter igual en la misma posición de nuestro objetivo se suma 1 al fitness
def algoritmoFitness(carIgual):
  fitness = 0
  for i in range(len(objetivo)):
    if objetivo[i] == carIgual[i]:
        fitness = fitness + 1
  return fitness

#Funcion para mutar a nuestra cadena original o padre
def mutar(padre):
    indice = random.randrange(0,len(padre))#Devuelve un número entre 0 y el tamaño de la lista
    genesDelHijo = list(padre)#crea una lista que contenga lo de la lista padre
    genNuevo, alternar = random.sample(alfabeto,2)#Devuelve 2 elementos aleatorios de la lista alfabeto, uno para genNuevo y otro para alternar
    if genNuevo == genesDelHijo[indice]:
      genesDelHijo[indice] = alternar
    else:
      genNuevo
    return ''.join(genesDelHijo)#une los caracteres de la cadena genesDelHijo sin separaciones

#Funcion para imprimir en pantalla los resultados
def imprimir(resultado,g):
    diferenciaDeTiempo = datetime.datetime.now() - tiempoDeInicio
    fitness = algoritmoFitness(resultado)
    print('{}\t{}\t{}\t{}'.format(g,resultado,fitness,diferenciaDeTiempo))


#Inicializamos nuestros parametros
print('{}\t{}\t{}\t{}'.format("GENERACION","RESULTADO","                        FITNESS","DIFERENCIA DE TIEMPO"))
generacion=0
mejorPadre = generarPadre(len(objetivo))
mejorFitness = algoritmoFitness(mejorPadre)
imprimir(mejorPadre,generacion)


#Creamos un ciclo para iterar nuestras funciones
#Hasta obtener nuestro objetivo
while True:
    generacion = generacion + 1
    hijo = mutar(mejorPadre)
    hijoConFitness = algoritmoFitness(hijo)
    if mejorFitness >= hijoConFitness:
        continue
    imprimir(hijo,generacion)
    if hijoConFitness >= len(mejorPadre):
        break
    mejorFitness = hijoConFitness
    mejorPadre = hijo
# Out:
# GENERACION	RESULTADO	                        FITNESS	DIFERENCIA DE TIEMPO
# 0	HjNbae VzÑg,vXMIDwKclGFCWPJxBnrAUQumLqñáOETkhyZ	0	0:00:00.001021
# 1012	HjNbae VzÑg,vXMIDwKclGFCWPJxBnrAUQimLqñáOETkhyZ	1	0:00:00.026583
# 5326	HjNbae VzÑg,vXMIDwKclGFCiPJxBnrAUQimLqñáOETkhyZ	2	0:00:00.138887
# 7323	HjNbae VzÑg,vXMrDwKclGFCiPJxBnrAUQimLqñáOETkhyZ	3	0:00:00.186363
# 10870	HjNbae VzÑg,vXMrmwKclGFCiPJxBnrAUQimLqñáOETkhyZ	4	0:00:00.274205
# 19514	HjNbae VzÑg,vXMrmáKclGFCiPJxBnrAUQimLqñáOETkhyZ	5	0:00:00.484336
# 22078	HjNbae VzÑg,vXormáKclGFCiPJxBnrAUQimLqñáOETkhyZ	6	0:00:00.555100
# 25363	HjNbae VzÑg,vXormáKclGFCiPtxBnrAUQimLqñáOETkhyZ	7	0:00:00.640154
# 27021	HjNbae VzÑg,vXormáKclGFCintxBnrAUQimLqñáOETkhyZ	8	0:00:00.677228
# 28241	HjNbae VzÑg,vXormáKclGFCintxlnrAUQimLqñáOETkhyZ	9	0:00:00.703959
# 31657	HjNbae rzÑg,vXormáKclGFCintxlnrAUQimLqñáOETkhyZ	10	0:00:00.782366
# 38769	HjNbae rzÑg,vXormáKclGFCintxlnrAUQimLqñáOfTkhyZ	11	0:00:00.944139
# 42308	HjNbae rzÑg,vXormáKclGFCintxlnrAUcimLqñáOfTkhyZ	12	0:00:01.026653
# 43387	HjNbae rzÑg,vXormáKclGFCintxlnrAUcimLqñáOfikhyZ	13	0:00:01.050254
# 45276	HjNbae rzÑg,vXormáKclGFCintxlnrAUcimLqráOfikhyZ	14	0:00:01.097511
# 46378	HjNbae rzÑg,vXormáKclGFCintxlnrAUcimLaráOfikhyZ	15	0:00:01.124687
# 47655	HjNbae rzÑ ,vXormáKclGFCintxlnrAUcimLaráOfikhyZ	16	0:00:01.157416
# 53245	HjNbae rzÑ ,vXormátclGFCintxlnrAUcimLaráOfikhyZ	17	0:00:01.306477
# 53495	HjNbae rzÑ ,vXormátclGFCintxlngAUcimLaráOfikhyZ	18	0:00:01.310621
# 61366	IjNbae rzÑ ,vXormátclGFCintxlngAUcimLaráOfikhyZ	19	0:00:01.429085
# 70656	IjNbai rzÑ ,vXormátclGFCintxlngAUcimLaráOfikhyZ	20	0:00:01.567696
# 70818	IjNbai rzÑ ,vXormátclGFCintxlngAUcimLaráOfichyZ	21	0:00:01.570509
# 74749	IjNbai rzÑ ,vXormátclGFCintxlngeUcimLaráOfichyZ	22	0:00:01.632910
# 78055	IjNbai rzÑ ,vXormátccGFCintxlngeUcimLaráOfichyZ	23	0:00:01.685105
# 83527	IjNbai rzÑ ,vXormátccGFCintxlngeUcim aráOfichyZ	24	0:00:01.768023
# 98173	InNbai rzÑ ,vXormátccGFCintxlngeUcim aráOfichyZ	25	0:00:01.981987
# 99983	InNbai rzÑ ,vXormátccGFCintxlngeUcim artOfichyZ	26	0:00:02.008904
# 100730	InNbai rzÑ ,vXormátccGFCintxligeUcim artOfichyZ	27	0:00:02.020417
# 108857	InNeai rzÑ ,vXormátccGFCintxligeUcim artOfichyZ	28	0:00:02.146695
# 109199	InNeai rzÑ ,vXormátccGFCintxligeUcim artOfichaZ	29	0:00:02.151754
# 115562	InNeai rzÑ ,vXormátccG,CintxligeUcim artOfichaZ	30	0:00:02.252409
# 115850	InNeai rzÑ ivXormátccG,CintxligeUcim artOfichaZ	31	0:00:02.256703
# 132614	InNeai rza ivXormátccG,CintxligeUcim artOfichaZ	32	0:00:02.503995
# 151267	InNeai rza ivXormátccG,Cintxligencim artOfichaZ	33	0:00:02.793511
# 160135	InNeai rza ivXormátccG,Cintxligencim artOficiaZ	34	0:00:02.923268
# 171085	InNeai rza ivXormátcca,Cintxligencim artOficiaZ	35	0:00:03.087213
# 178493	InNeai rza ivXormátcca,Cintxligencim artificiaZ	36	0:00:03.219279
# 188272	InNeai ría ivXormátcca,Cintxligencim artificiaZ	37	0:00:03.370130
# 200222	InNeai ría ivXormática,Cintxligencim artificiaZ	38	0:00:03.549129
# 203288	InNeai ría ivformática,Cintxligencim artificiaZ	39	0:00:03.598183
# 240990	InNeai ría informática,Cintxligencim artificiaZ	40	0:00:04.157301
# 314720	InNeaiería informática,Cintxligencim artificiaZ	41	0:00:05.248810
# 333513	InNeniería informática,Cintxligencim artificiaZ	42	0:00:05.534048
# 354155	InNeniería informática,Cintxligencia artificiaZ	43	0:00:05.844595
# 411849	InNeniería informática,Cinteligencia artificiaZ	44	0:00:06.715037
# 422669	Ingeniería informática,Cinteligencia artificiaZ	45	0:00:06.874284
# 447933	Ingeniería informática, inteligencia artificiaZ	46	0:00:07.254039
# 596943	Ingeniería informática, inteligencia artificial	47	0:00:09.472703
